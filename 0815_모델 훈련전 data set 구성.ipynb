# %%
#-*- coding: utf-8 -*-

import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
from pandas import DataFrame, Series
from sklearn.preprocessing import LabelEncoder

# %matplotlib inline

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
phone_brand_device_model = pd.read_csv('data/phone_brand_device_model.csv')
gender_age_train = pd.read_csv('data/gender_age_train.csv')
label_categories = pd.read_csv('data/label_categories.csv')
events = pd.read_csv('data/events.csv')
app_labels = pd.read_csv('data/app_labels.csv')
app_events = pd.read_csv('data/app_events.csv', dtype = {'event_id' : np.int8, 'app_id' : np.int64, 
                                                   'is_installed' : np.int8, 'is_active' : np.int8})
gender_age_test = pd.read_csv('data/gender_age_test.csv')

# %% [markdown]
# ### TimeStamp Split

# %%
events['timestamp'].replace('-', '', regex = True, inplace = True)
events['timestamp'].replace(':', '', regex = True, inplace = True)
events['timestamp'].replace(' ', '', regex = True, inplace = True)

events['year'] = events['timestamp'].map(lambda x: x[0:4])
events['month'] = events['timestamp'].map(lambda x: x[4:6])
events['day'] = events['timestamp'].map(lambda x: x[6:8])
events['time'] = events['timestamp'].map(lambda x: x[8:10])

events.drop(['timestamp'], axis = 1, inplace = True)
events.drop(['year'], axis = 1, inplace = True)

event_mean = events.groupby('device_id', as_index = False).agg({'longitude' : 'mean', 
                                                   'latitude' : 'mean'})

events_tude_mean = pd.merge(events, event_mean, on = 'device_id')

events_tude_mean = events_tude_mean.drop('longitude_x', 1)
events_tude_mean = events_tude_mean.drop('latitude_x', 1)

# %% [markdown]
# ### 명목형 변수 치환

# %%
phone_brand_device_model.phone_brand.fillna(phone_brand_device_model.phone_brand.dropna().max(), inplace = True)
phone_brand_device_model.device_model.fillna(phone_brand_device_model.device_model.dropna().max(), inplace = True)

# %%
le = LabelEncoder()

phone_brand_device_model['brand'] = le.fit_transform(phone_brand_device_model['phone_brand'])
phone_brand_device_model['device'] = le.fit_transform(phone_brand_device_model['device_model'])



phone_brand_label = phone_brand_device_model.copy()

phone_brand_label = phone_brand_label.drop('phone_brand', 1)
phone_brand_label = phone_brand_label.drop('device_model', 1)

# %%
# M = 1, F = 0
gender_age_train['M_F'] = le.fit_transform(gender_age_train['gender'])

# %%
# group 치환
gender_age_train['group_e'] = le.fit_transform(gender_age_train['group'])

# %%
gender_age_train.head()
# Out:
#              device_id gender  age   group  M_F  group_e
# 0 -8076087639492063270      M   35  M32-38    1       10
# 1 -2897161552818060146      M   35  M32-38    1       10
# 2 -8260683887967679142      M   35  M32-38    1       10
# 3 -4938849341048082022      M   30  M29-31    1        9
# 4   245133531816851882      M   30  M29-31    1        9

# %% [markdown]
# ### test set 기초자료

# %%
t1 = pd.merge(gender_age_test, phone_brand_device_model, on = 'device_id')
t2 = pd.merge(t1, events, on = 'device_id')
t3 = pd.merge(t2, app_events, on = 'event_id')
t4 = pd.merge(t3, app_labels, on = 'app_id')

# %%
t4 = t4.loc[:, ['device_id', 'event_id', 'app_id', 'label_id', 'brand', 'device', 'time']]

# %%
t4.head()
# Out:
#              device_id  event_id               app_id  label_id  brand  \
# 0  5317828258152702819       114 -7377004479023402858       549     13
# 1  5317828258152702819       114 -7377004479023402858       721     13
# 2  5317828258152702819       114 -7377004479023402858       704     13
# 3  5317828258152702819       114 -7377004479023402858       302     13
# 4  5317828258152702819       114 -7377004479023402858       303     13
#
#    device time
# 0    1259   00
# 1    1259   00
# 2    1259   00
# 3    1259   00
# 4    1259   00

# %% [markdown]
# ### longitude / latitude mean값으로 변경
# * dvice_id에 따른 지역 편차 줄임

# %%
event_mean = events.groupby('device_id', as_index = False).agg({'longitude' : 'mean', 
                                                   'latitude' : 'mean'})

events_tude_mean = pd.merge(events, event_mean, on = 'device_id')

events_tude_mean = events_tude_mean.drop('longitude_x', 1)
events_tude_mean = events_tude_mean.drop('latitude_x', 1)

# %% [markdown]
# ### brand 별 연령대

# %%
age_brand = pd.merge(phone_brand_device_model, gender_age_train, how = 'left', on = 'device_id')

# %%
age_bran_time = pd.merge(age_brand, events, how = 'left', on = 'device_id')

# %%
# 명목 변수 제거

age_bran_time_e = age_bran_time[['device_id', 'brand', 'device', 'age', 'M_F', 'group_e', 'event_id', 'longitude', 'latitude', 'time']]

# %%
age_bran_time_e.head()
# Out:
#              device_id  brand  device   age  M_F  group_e   event_id  \
# 0 -8890648629457979026     51    1517  33.0  1.0     10.0        NaN
# 1  1277779817574759137     51     749  26.0  1.0      7.0        NaN
# 2  5137427614288105724     15     560   NaN  NaN      NaN   571915.0
# 3  5137427614288105724     15     560   NaN  NaN      NaN  1414484.0
# 4  5137427614288105724     15     560   NaN  NaN      NaN  3049420.0
#
#    longitude  latitude time
# 0        NaN       NaN  NaN
# 1        NaN       NaN  NaN
# 2        0.0       0.0   08
# 3        0.0       0.0   22
# 4        0.0       0.0   08

# %% [markdown]
# ## 변수 추가
# * brand별 연령대
# * model별 연령대
# * time(hour)별 연령대
# * label별 연령대

# %%
g_brand = pd.DataFrame()
g_model = pd.DataFrame()

g_brand_tmp = pd.DataFrame()
g_model_tmp = pd.DataFrame()

# phone_brand 평균 연령대

#g_brand['brand_age'] = age_brand.groupby('phone_brand', 'group_e')['age'].mean().astype(np.float32)
#g_brand['brand_gender'] = age_brand.groupby('phone_brand', 'group_e')['M_F'].mean().astype(np.float32)
#g_brand['brand_group'] = age_brand.groupby('phone_brand')['group_e'].mean().astype(np.float32)
g_brand['brand_group_count'] = age_brand.groupby(['phone_brand','group_e'])['group_e'].count()
g_brand_tmp['brand_group_sum'] = age_brand.groupby('phone_brand')['group_e'].sum()

g_brand = g_brand.reset_index()
g_brand_tmp = g_brand_tmp.reset_index()
g_brand_rate = pd.merge(g_brand, g_brand_tmp, how = 'left', on = 'phone_brand')

#g_model['model_age'] = age_brand.groupby('device_model', 'group_e')['age'].mean().astype(np.float32)
#g_model['model_gender'] = age_brand.groupby('device_model', 'group_e')['M_F'].mean().astype(np.float32)
#g_model['model_group'] = age_brand.groupby('device_model')['group_e'].mean().astype(np.float32)
g_model['model_group_count'] = age_brand.groupby(['device_model', 'group_e'])['group_e'].count()
g_model_tmp['model_group_sum'] = age_brand.groupby('device_model')['group_e'].sum()

g_model = g_model.reset_index()
g_model_tmp = g_model_tmp.reset_index()
g_model_rate= pd.merge(g_model, g_model_tmp, how = 'left', on = 'device_model')

g_brand_rate['brand_ratio'] = g_brand_rate.brand_group_count / g_brand_rate.brand_group_sum
g_model_rate['device_ratio'] = g_model_rate.model_group_count / g_model_rate.model_group_sum

# %%
g_brand_rate.head()
# Out:
#   phone_brand  group_e  brand_group_count  brand_group_sum  brand_ratio
# 0          E派      0.0                  2             57.0     0.035088
# 1          E派      2.0                  2             57.0     0.035088
# 2          E派      6.0                  1             57.0     0.017544
# 3          E派      8.0                  1             57.0     0.017544
# 4          E派      9.0                  1             57.0     0.017544

# %%
g_model_rate.head()
# Out:
#   device_model  group_e  model_group_count  model_group_sum  device_ratio
# 0         1100      0.0                  1             36.0      0.027778
# 1         1100      3.0                  4             36.0      0.111111
# 2         1100      7.0                  2             36.0      0.055556
# 3         1100     10.0                  1             36.0      0.027778
# 4         1105      0.0                  1            387.0      0.002584

# %% [markdown]
# ### time별 그룹 비율

# %%
g_time_sum = pd.DataFrame()
g_time_sum['time_sum'] = age_bran_time_e.groupby('time')['group_e'].count()

g_tmp = g_tmp.reset_index()

g_time_sum = g_time_sum.reset_index()

g_tmp_ = pd.merge(g_tmp, g_time_sum, on = 'time')

# 시간대별 사용자그룹 분포
g_tmp_['time_g_ratio'] = g_tmp_.group_size / g_tmp_.time_sum

# %%
g_tmp_.head()
# Out:
#   time  group_e  group_size  time_sum  time_g_ratio
# 0   00      0.0        1403     45058      0.031138
# 1   00      1.0        1485     45058      0.032958
# 2   00      2.0        1339     45058      0.029717
# 3   00      3.0        1893     45058      0.042013
# 4   00      4.0        2679     45058      0.059457

# %% [markdown]
# ### label별 그룹 ratio

# %%
age_bran_time_app = pd.merge(age_bran_time, app_events, how = 'left', on = 'event_id')
age_bran_time_app_label = pd.merge(age_bran_time_app, app_labels, how = 'left', on = 'app_id')

# %%
g_app_label = pd.DataFrame()
g_app_label_sum = pd.DataFrame()

g_app_label['count'] = age_bran_time_app_label.groupby(['label_id', 'group_e'])['group_e'].count()
g_app_label_sum['sum'] = age_bran_time_app_label.groupby('label_id')['group_e'].sum()

g_app_label = g_app_label.reset_index()
g_app_label_sum = g_app_label_sum.reset_index()

g_label_group = pd.merge(g_app_label, g_app_label_sum, how = 'left', on = 'label_id')

g_label_group['label_ratio'] = g_label_group['count'] / g_label_group['sum']

# %%
g_label_group.head()
# Out:
#    label_id  group_e  count    sum  label_ratio
# 0      13.0      0.0      1  332.0     0.003012
# 1      13.0      2.0      4  332.0     0.012048
# 2      13.0      3.0      2  332.0     0.006024
# 3      13.0      5.0      1  332.0     0.003012
# 4      13.0      6.0      5  332.0     0.015060

# %%
age_bran_time_app_label.head()
# Out:
#              device_id phone_brand device_model  brand  device gender   age  \
# 0 -8890648629457979026          小米           红米     51    1517      M  33.0
# 1  1277779817574759137          小米         MI 2     51     749      M  26.0
# 2  5137427614288105724          三星    Galaxy S4     15     560    NaN   NaN
# 3  5137427614288105724          三星    Galaxy S4     15     560    NaN   NaN
# 4  5137427614288105724          三星    Galaxy S4     15     560    NaN   NaN
#
#     group  M_F  group_e     event_id  longitude  latitude month  day time  \
# 0  M32-38  1.0     10.0          NaN        NaN       NaN   NaN  NaN  NaN
# 1  M23-26  1.0      7.0          NaN        NaN       NaN   NaN  NaN  NaN
# 2     NaN  NaN      NaN       571915        0.0       0.0    05   07   08
# 3     NaN  NaN      NaN  1.41448e+06        0.0       0.0    05   07   22
# 4     NaN  NaN      NaN  3.04942e+06        0.0       0.0    05   07   08
#
#   app_id  is_installed  is_active  label_id
# 0    NaN           NaN        NaN       NaN
# 1    NaN           NaN        NaN       NaN
# 2    NaN           NaN        NaN       NaN
# 3    NaN           NaN        NaN       NaN
# 4    NaN           NaN        NaN       NaN

# %% [markdown]
# ### MERGE 본체

# %%
total = age_bran_time_app_label[['device_id', 'phone_brand', 'device_model', 'brand', 'device', 'M_F','age', 'group_e', 'event_id',
                                'longitude', 'latitude', 'time', 'app_id', 'label_id']]

# %%
total_b = pd.merge(total, g_brand_rate, how = 'left', on = ['phone_brand', 'group_e'])

# %%
total_m = pd.merge(total_b, g_model_rate, how = 'left', on = ['device_model', 'group_e'])

# %%
total_all = pd.merge(total_m, g_label_group, how = 'left', on = ['label_id', 'group_e'])

# %%
tmp = pd.merge(age_bran_time_e, g_tmp_, how = 'left', on = ['group_e', 'time'])

#tmp = tmp[['device_id', 'brand', 'device', 'age', 'M_F', 'group_e', 'event_id', 'longitude', 'latitude', 'time', 'time_g_ratio']]

# %%
total_all.head()
# Out:
#              device_id phone_brand device_model  brand  device  M_F   age  \
# 0 -8890648629457979026          小米           红米     51    1517  1.0  33.0
# 1  1277779817574759137          小米         MI 2     51     749  1.0  26.0
# 2  5137427614288105724          三星    Galaxy S4     15     560  NaN   NaN
# 3  5137427614288105724          三星    Galaxy S4     15     560  NaN   NaN
# 4  5137427614288105724          三星    Galaxy S4     15     560  NaN   NaN
#
#    group_e     event_id  longitude  latitude time app_id  label_id  \
# 0     10.0          NaN        NaN       NaN  NaN    NaN       NaN
# 1      7.0          NaN        NaN       NaN  NaN    NaN       NaN
# 2      NaN       571915        0.0       0.0   08    NaN       NaN
# 3      NaN  1.41448e+06        0.0       0.0   22    NaN       NaN
# 4      NaN  3.04942e+06        0.0       0.0   08    NaN       NaN
#
#    brand_group_count  brand_group_sum  brand_ratio  model_group_count  \
# 0             2147.0         111483.0     0.019259              129.0
# 1             2440.0         111483.0     0.021887               88.0
# 2                NaN              NaN          NaN                NaN
# 3                NaN              NaN          NaN                NaN
# 4                NaN              NaN          NaN                NaN
#
#    model_group_sum  device_ratio  count  sum  label_ratio
# 0           6300.0      0.020476    NaN  NaN          NaN
# 1           3476.0      0.025316    NaN  NaN          NaN
# 2              NaN           NaN    NaN  NaN          NaN
# 3              NaN           NaN    NaN  NaN          NaN
# 4              NaN           NaN    NaN  NaN          NaN

# %%
total_e = total_all.loc[:,['group_e', 'device_id', 'app_id', 'label_id', 'brand', 'device', 'M_F', 'age',  'time',  'brand_ratio', 
                           'device_ratio', 'label_ratio']]

# %%
# train / test 분리

# %%
total_train = pd.merge(gender_age_train, total_e, on = 'device_id')
total_test = pd.merge(gender_age_test, total_e, on = 'device_id')

# %%
total_train.head()
# Out:
#              device_id gender  age_x   group  M_F_x  group_e_x  group_e_y  \
# 0 -8076087639492063270      M     35  M32-38      1         10       10.0
# 1 -2897161552818060146      M     35  M32-38      1         10       10.0
# 2 -8260683887967679142      M     35  M32-38      1         10       10.0
# 3 -4938849341048082022      M     30  M29-31      1          9        9.0
# 4   245133531816851882      M     30  M29-31      1          9        9.0
#
#   app_id  label_id  brand  device  M_F_y  age_y time  brand_ratio  \
# 0    NaN       NaN     51     749    1.0   35.0  NaN     0.019259
# 1    NaN       NaN     51     749    1.0   35.0  NaN     0.019259
# 2    NaN       NaN     51     749    1.0   35.0   14     0.019259
# 3    NaN       NaN     51    1524    1.0   30.0  NaN     0.015841
# 4    NaN       NaN     51     753    1.0   30.0  NaN     0.015841
#
#    device_ratio  label_ratio
# 0      0.022727          NaN
# 1      0.022727          NaN
# 2      0.022727          NaN
# 3      0.015513          NaN
# 4      0.016329          NaN

# %%
total_test.head(300)
# Out:
#                device_id  group_e app_id  label_id  brand  device  M_F  age  \
# 0    1002079943728939269      NaN    NaN       NaN     51    1482  NaN  NaN
# 1    1002079943728939269      NaN    NaN       NaN     51    1482  NaN  NaN
# 2    1002079943728939269      NaN    NaN       NaN     51    1482  NaN  NaN
# 3    1002079943728939269      NaN    NaN       NaN     51    1482  NaN  NaN
# 4    1002079943728939269      NaN    NaN       NaN     51    1482  NaN  NaN
# 5    1002079943728939269      NaN    NaN       NaN     51    1482  NaN  NaN
# 6    1002079943728939269      NaN    NaN       NaN     51    1482  NaN  NaN
# 7   -1547860181818787117      NaN    NaN       NaN     51    1519  NaN  NaN
# 8   -1547860181818787117      NaN    NaN       NaN     51    1519  NaN  NaN
# 9   -1547860181818787117      NaN    NaN       NaN     51    1519  NaN  NaN
# 10  -1547860181818787117      NaN    NaN       NaN     51    1519  NaN  NaN
# 11  -1547860181818787117      NaN    NaN       NaN     51    1519  NaN  NaN
# 12  -1547860181818787117      NaN    NaN       NaN     51    1519  NaN  NaN
# 13  -1547860181818787117      NaN    NaN       NaN     51    1519  NaN  NaN
# 14  -1547860181818787117      NaN    NaN       NaN     51    1519  NaN  NaN
# 15   7374582448058474277      NaN    NaN       NaN     31    1371  NaN  NaN
# 16   7374582448058474277      NaN    NaN       NaN     31    1371  NaN  NaN
# 17   7374582448058474277      NaN    NaN       NaN     31    1371  NaN  NaN
# 18   7374582448058474277      NaN    NaN       NaN     31    1371  NaN  NaN
# 19   7374582448058474277      NaN    NaN       NaN     31    1371  NaN  NaN
# 20  -6220210354783429585      NaN    NaN       NaN     31    1544  NaN  NaN
# 21  -6220210354783429585      NaN    NaN       NaN     31    1544  NaN  NaN
# 22  -6220210354783429585      NaN    NaN       NaN     31    1544  NaN  NaN
# 23  -6220210354783429585      NaN    NaN       NaN     31    1544  NaN  NaN
# 24  -6220210354783429585      NaN    NaN       NaN     31    1544  NaN  NaN
# 25  -6220210354783429585      NaN    NaN       NaN     31    1544  NaN  NaN
# 26  -6220210354783429585      NaN    NaN       NaN     31    1544  NaN  NaN
# 27  -6220210354783429585      NaN    NaN       NaN     31    1544  NaN  NaN
# 28  -6220210354783429585      NaN    NaN       NaN     31    1544  NaN  NaN
# 29  -5893464122623104785      NaN    NaN       NaN     51     749  NaN  NaN
# 30  -7560708697029818408      NaN    NaN       NaN     51     749  NaN  NaN
# 31    289797889702373958      NaN    NaN       NaN     51    1524  NaN  NaN
# 32   -402874006399730161      NaN    NaN       NaN     51    1524  NaN  NaN
# 33   5751283639860028129      NaN    NaN       NaN     15     560  NaN  NaN
# 34   -848943298935149395      NaN    NaN       NaN     15     560  NaN  NaN
# 35   6873889408535437611      NaN    NaN       NaN    128     772  NaN  NaN
# 36   9097600484609173263      NaN    NaN       NaN     51    1524  NaN  NaN
# 37   9097600484609173263      NaN    NaN       NaN     51    1524  NaN  NaN
# 38   9097600484609173263      NaN    NaN       NaN     51    1524  NaN  NaN
# 39   9097600484609173263      NaN    NaN       NaN     51    1524  NaN  NaN
# 40   9097600484609173263      NaN    NaN       NaN     51    1524  NaN  NaN
# 41   9097600484609173263      NaN    NaN       NaN     51    1524  NaN  NaN
# 42   9097600484609173263      NaN    NaN       NaN     51    1524  NaN  NaN
# 43   9097600484609173263      NaN    NaN       NaN     51    1524  NaN  NaN
# 44   9097600484609173263      NaN    NaN       NaN     51    1524  NaN  NaN
# 45   9097600484609173263      NaN    NaN       NaN     51    1524  NaN  NaN
# 46   9097600484609173263      NaN    NaN       NaN     51    1524  NaN  NaN
# 47   9097600484609173263      NaN    NaN       NaN     51    1524  NaN  NaN
# 48   9097600484609173263      NaN    NaN       NaN     51    1524  NaN  NaN
# 49   9097600484609173263      NaN    NaN       NaN     51    1524  NaN  NaN
# 50   9097600484609173263      NaN    NaN       NaN     51    1524  NaN  NaN
# 51   9097600484609173263      NaN    NaN       NaN     51    1524  NaN  NaN
# 52   9097600484609173263      NaN    NaN       NaN     51    1524  NaN  NaN
# 53   9097600484609173263      NaN    NaN       NaN     51    1524  NaN  NaN
# 54   9097600484609173263      NaN    NaN       NaN     51    1524  NaN  NaN
# 55   9097600484609173263      NaN    NaN       NaN     51    1524  NaN  NaN
# 56   9097600484609173263      NaN    NaN       NaN     51    1524  NaN  NaN
# 57   9097600484609173263      NaN    NaN       NaN     51    1524  NaN  NaN
# 58   9097600484609173263      NaN    NaN       NaN     51    1524  NaN  NaN
# 59   9097600484609173263      NaN    NaN       NaN     51    1524  NaN  NaN
# 60   9097600484609173263      NaN    NaN       NaN     51    1524  NaN  NaN
# 61   9097600484609173263      NaN    NaN       NaN     51    1524  NaN  NaN
# 62   9097600484609173263      NaN    NaN       NaN     51    1524  NaN  NaN
# 63   9097600484609173263      NaN    NaN       NaN     51    1524  NaN  NaN
# 64   9097600484609173263      NaN    NaN       NaN     51    1524  NaN  NaN
# 65   9097600484609173263      NaN    NaN       NaN     51    1524  NaN  NaN
# 66   9097600484609173263      NaN    NaN       NaN     51    1524  NaN  NaN
# 67   9097600484609173263      NaN    NaN       NaN     51    1524  NaN  NaN
# 68   9097600484609173263      NaN    NaN       NaN     51    1524  NaN  NaN
# 69   9097600484609173263      NaN    NaN       NaN     51    1524  NaN  NaN
# 70   9097600484609173263      NaN    NaN       NaN     51    1524  NaN  NaN
# 71   9097600484609173263      NaN    NaN       NaN     51    1524  NaN  NaN
# 72   9097600484609173263      NaN    NaN       NaN     51    1524  NaN  NaN
# 73   9097600484609173263      NaN    NaN       NaN     51    1524  NaN  NaN
# 74   9097600484609173263      NaN    NaN       NaN     51    1524  NaN  NaN
# 75   9097600484609173263      NaN    NaN       NaN     51    1524  NaN  NaN
# 76   9097600484609173263      NaN    NaN       NaN     51    1524  NaN  NaN
# 77   9097600484609173263      NaN    NaN       NaN     51    1524  NaN  NaN
# 78   9097600484609173263      NaN    NaN       NaN     51    1524  NaN  NaN
# 79   9097600484609173263      NaN    NaN       NaN     51    1524  NaN  NaN
# 80   9097600484609173263      NaN    NaN       NaN     51    1524  NaN  NaN
# 81   9097600484609173263      NaN    NaN       NaN     51    1524  NaN  NaN
# 82   9097600484609173263      NaN    NaN       NaN     51    1524  NaN  NaN
# 83   7918118984690678938      NaN    NaN       NaN     15     536  NaN  NaN
# 84  -5723359257508971431      NaN    NaN       NaN     31     778  NaN  NaN
# 85  -5723359257508971431      NaN    NaN       NaN     31     778  NaN  NaN
# 86  -5723359257508971431      NaN    NaN       NaN     31     778  NaN  NaN
# 87  -5045999078783569038      NaN    NaN       NaN     15     537  NaN  NaN
# 88  -4466603005916311099      NaN    NaN       NaN     31    1556  NaN  NaN
# 89   6130118150534832946      NaN    NaN       NaN     31     268  NaN  NaN
# 90   6130118150534832946      NaN    NaN       NaN     31     268  NaN  NaN
# 91   6130118150534832946      NaN    NaN       NaN     31     268  NaN  NaN
# 92   6130118150534832946      NaN    NaN       NaN     31     268  NaN  NaN
# 93   6130118150534832946      NaN    NaN       NaN     31     268  NaN  NaN
# 94   6130118150534832946      NaN    NaN       NaN     31     268  NaN  NaN
# 95   6130118150534832946      NaN    NaN       NaN     31     268  NaN  NaN
# 96   6130118150534832946      NaN    NaN       NaN     31     268  NaN  NaN
# 97   6130118150534832946      NaN    NaN       NaN     31     268  NaN  NaN
# 98   6130118150534832946      NaN    NaN       NaN     31     268  NaN  NaN
# 99   6130118150534832946      NaN    NaN       NaN     31     268  NaN  NaN
# 100  6130118150534832946      NaN    NaN       NaN     31     268  NaN  NaN
# 101  6130118150534832946      NaN    NaN       NaN     31     268  NaN  NaN
# 102  6130118150534832946      NaN    NaN       NaN     31     268  NaN  NaN
# 103  6130118150534832946      NaN    NaN       NaN     31     268  NaN  NaN
# 104  6130118150534832946      NaN    NaN       NaN     31     268  NaN  NaN
# 105  6130118150534832946      NaN    NaN       NaN     31     268  NaN  NaN
# 106  6130118150534832946      NaN    NaN       NaN     31     268  NaN  NaN
# 107  6130118150534832946      NaN    NaN       NaN     31     268  NaN  NaN
# 108  6130118150534832946      NaN    NaN       NaN     31     268  NaN  NaN
# 109  6130118150534832946      NaN    NaN       NaN     31     268  NaN  NaN
# 110  6130118150534832946      NaN    NaN       NaN     31     268  NaN  NaN
# 111  6130118150534832946      NaN    NaN       NaN     31     268  NaN  NaN
# 112  6130118150534832946      NaN    NaN       NaN     31     268  NaN  NaN
# 113  6130118150534832946      NaN    NaN       NaN     31     268  NaN  NaN
# 114  6130118150534832946      NaN    NaN       NaN     31     268  NaN  NaN
# 115  6130118150534832946      NaN    NaN       NaN     31     268  NaN  NaN
# 116  6130118150534832946      NaN    NaN       NaN     31     268  NaN  NaN
# 117  6130118150534832946      NaN    NaN       NaN     31     268  NaN  NaN
# 118  6130118150534832946      NaN    NaN       NaN     31     268  NaN  NaN
# 119  6130118150534832946      NaN    NaN       NaN     31     268  NaN  NaN
# 120  6130118150534832946      NaN    NaN       NaN     31     268  NaN  NaN
# 121  6130118150534832946      NaN    NaN       NaN     31     268  NaN  NaN
# 122  6130118150534832946      NaN    NaN       NaN     31     268  NaN  NaN
# 123  6130118150534832946      NaN    NaN       NaN     31     268  NaN  NaN
# 124  6130118150534832946      NaN    NaN       NaN     31     268  NaN  NaN
# 125  6130118150534832946      NaN    NaN       NaN     31     268  NaN  NaN
# 126  6130118150534832946      NaN    NaN       NaN     31     268  NaN  NaN
# 127  6130118150534832946      NaN    NaN       NaN     31     268  NaN  NaN
# 128  6130118150534832946      NaN    NaN       NaN     31     268  NaN  NaN
# 129  6130118150534832946      NaN    NaN       NaN     31     268  NaN  NaN
# 130  6130118150534832946      NaN    NaN       NaN     31     268  NaN  NaN
# 131  6130118150534832946      NaN    NaN       NaN     31     268  NaN  NaN
# 132  6130118150534832946      NaN    NaN       NaN     31     268  NaN  NaN
#
# 225   06          NaN           NaN          NaN
# 226   08          NaN           NaN          NaN
# 227   15          NaN           NaN          NaN
# 228   15          NaN           NaN          NaN
# 229   17          NaN           NaN          NaN
# 230   06          NaN           NaN          NaN
# 231   07          NaN           NaN          NaN
# 232   08          NaN           NaN          NaN
# 233   07          NaN           NaN          NaN
# 234   09          NaN           NaN          NaN
# 235   20          NaN           NaN          NaN
# 236   07          NaN           NaN          NaN
# 237   07          NaN           NaN          NaN
# 238   14          NaN           NaN          NaN
# 239   15          NaN           NaN          NaN
# 240   17          NaN           NaN          NaN
# 241   17          NaN           NaN          NaN
# 242   06          NaN           NaN          NaN
# 243   07          NaN           NaN          NaN
# 244   15          NaN           NaN          NaN
# 245   07          NaN           NaN          NaN
# 246   15          NaN           NaN          NaN
# 247   17          NaN           NaN          NaN
# 248   06          NaN           NaN          NaN
# 249   07          NaN           NaN          NaN
# 250   07          NaN           NaN          NaN
# 251   22          NaN           NaN          NaN
# 252   07          NaN           NaN          NaN
# 253   15          NaN           NaN          NaN
# 254   22          NaN           NaN          NaN
# 255   09          NaN           NaN          NaN
# 256   15          NaN           NaN          NaN
# 257   15          NaN           NaN          NaN
# 258   08          NaN           NaN          NaN
# 259   15          NaN           NaN          NaN
# 260   09          NaN           NaN          NaN
# 261   17          NaN           NaN          NaN
# 262   07          NaN           NaN          NaN
# 263   15          NaN           NaN          NaN
# 264   09          NaN           NaN          NaN
# 265   13          NaN           NaN          NaN
# 266   17          NaN           NaN          NaN
# 267   21          NaN           NaN          NaN
# 268   07          NaN           NaN          NaN
# 269   22          NaN           NaN          NaN
# 270   06          NaN           NaN          NaN
# 271   08          NaN           NaN          NaN
# 272   06          NaN           NaN          NaN
# 273   06          NaN           NaN          NaN
# 274   07          NaN           NaN          NaN
# 275   09          NaN           NaN          NaN
# 276   05          NaN           NaN          NaN
# 277   12          NaN           NaN          NaN
# 278   17          NaN           NaN          NaN
# 279   19          NaN           NaN          NaN
# 280   06          NaN           NaN          NaN
# 281   07          NaN           NaN          NaN
# 282   19          NaN           NaN          NaN
# 283   14          NaN           NaN          NaN
# 284   07          NaN           NaN          NaN
# 285   08          NaN           NaN          NaN
# 286   14          NaN           NaN          NaN
# 287   17          NaN           NaN          NaN
# 288   13          NaN           NaN          NaN
# 289   15          NaN           NaN          NaN
# 290   22          NaN           NaN          NaN
# 291   06          NaN           NaN          NaN
# 292   22          NaN           NaN          NaN
# 293   06          NaN           NaN          NaN
# 294   14          NaN           NaN          NaN
# 295   14          NaN           NaN          NaN
# 296   07          NaN           NaN          NaN
# 297   07          NaN           NaN          NaN
# 298   07          NaN           NaN          NaN
# 299   15          NaN           NaN          NaN

# %% [markdown]
# ### device_id 1개로 줄이기 (보류)

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
oh = OneHotEncoder(categorical_features = )

# %%
age_brand = age_brand.join(g_user, on = 'phone_brand', rsuffix = '_')

# %%
age_brand = age_brand.drop('brand_age', 1)

# %%
age_brand.head()
# Out:
#              device_id phone_brand   device_model  brand  device gender   age  \
# 0 -8890648629457979026          小米             红米     51    1517      M  33.0
# 1  1277779817574759137          小米           MI 2     51     749      M  26.0
# 2  5137427614288105724          三星      Galaxy S4     15     560    NaN   NaN
# 3  3669464369358936369       SUGAR           时尚手机      9    1503    NaN   NaN
# 4 -5019277647504317457          三星  Galaxy Note 2     15     536      F  32.0
#
#     group  brand_age_
# 0  M32-38   30.986849
# 1  M23-26   30.986849
# 2     NaN   32.966949
# 3     NaN   28.500000
# 4  F29-32   32.966949

# %% [markdown]
# ### test set 구성

# %%
age_even = pd.merge(gender_age_train, events_tude_mean, how = 'left', on = 'device_id')
age_app = pd.merge(age_even, app_events, how = 'left', on = 'event_id')
age_label = pd.merge(age_app, app_labels, how='left', on='app_id')
age_model = pd.merge(age_label, phone_brand_label, how = 'left', on = 'device_id')

train_f = age_model.loc[:, ['device_id', 'label_id', 'brand', 'device']] # time 붙일 수 있다.

X = train_f

age_model['group_label'] = le.fit_transform(age_model['group'])
y = age_model.group_label

X.fillna(-1, inplace = True)
y.fillna(-1, inplace = True)

# %% [markdown]
# ### test set 구성

# %%
test_e = pd.merge(gender_age_test, events_tude_mean, how = 'left', on = 'device_id')
test_app = pd.merge(test_e, app_events, how = 'left', on = 'event_id')
test_app_label = pd.merge(test_app, app_labels, how='left', on = 'app_id')
test_model = pd.merge(test_app_label, phone_brand_label, how = 'left', on = 'device_id')

test_model.fillna(-1, inplace = True)

# %%
test_model.head(10)
# Out:
#              device_id   event_id month day time  longitude_y  latitude_y  \
# 0  1002079943728939269   460577.0    05  03   21          0.0         0.0
# 1  1002079943728939269   755837.0    05  05   22          0.0         0.0
# 2  1002079943728939269  1171252.0    05  02   08          0.0         0.0
# 3  1002079943728939269  1805074.0    05  01   16          0.0         0.0
# 4  1002079943728939269  2145937.0    05  05   08          0.0         0.0
# 5  1002079943728939269  2774265.0    05  07   09          0.0         0.0
# 6  1002079943728939269  3127685.0    05  06   22          0.0         0.0
# 7 -1547860181818787117   185516.0    05  03   20          0.0         0.0
# 8 -1547860181818787117   202176.0    05  01   13          0.0         0.0
# 9 -1547860181818787117   604418.0    05  01   13          0.0         0.0
#
#    app_id  is_installed  is_active  label_id  brand  device
# 0    -1.0          -1.0       -1.0      -1.0     51    1482
# 1    -1.0          -1.0       -1.0      -1.0     51    1482
# 2    -1.0          -1.0       -1.0      -1.0     51    1482
# 3    -1.0          -1.0       -1.0      -1.0     51    1482
# 4    -1.0          -1.0       -1.0      -1.0     51    1482
# 5    -1.0          -1.0       -1.0      -1.0     51    1482
# 6    -1.0          -1.0       -1.0      -1.0     51    1482
# 7    -1.0          -1.0       -1.0      -1.0     51    1519
# 8    -1.0          -1.0       -1.0      -1.0     51    1519
# 9    -1.0          -1.0       -1.0      -1.0     51    1519

# %% [markdown]
# ## train_test_split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 1)

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
forest = RandomForestClassifier(criterion = 'gini', n_estimators = 10, random_state = 1, n_jobs = -1)

# %%
forest.fit(X_train[['label_id', 'brand', 'device']], y_train)

# %%
forest.feature_importances_

# %%
result_rf = pd.DataFrame(y_prona_rf_test, columns = le.classes_)
device_id = test_model["device_id"].values
result_rf['device_id'] = device_id  
result_rf = result_rf.set_index('device_id')
result_rf = result_rf.drop_duplicates(['device_id'], keep='first')

# %% [markdown]
# # 예측

# %%
y_prona_rf_test = forest.predict_proba(test_model[['label_id', 'brand', 'device']])

# %%
from sklearn.metrics import accuracy_score
